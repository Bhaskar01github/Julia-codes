# %% [markdown]
# # Plotting
#
# ## Basics
# There are a few different ways to plot in Julia (including calling PyPlot). <br>
#
# Here we'll show you how to use `Plots.jl`.  If it's not installed yet, you need to use the package manager to install it, and Julia will precompile it for you the first time you use it:

# %%
using Plots
plot(sin,0,2*π,)
# Out:
# Couldn't process recipe args: (typeof(sin), Int64, Float64, Int64)
#
#
#
# Stacktrace:
#
#  [1] error(s::String)
#
#    @ Base .\error.jl:35
#
#  [2] macro expansion
#
#    @ C:\Users\BHASKAR BARMAN\.julia\packages\RecipesPipeline\XxUHt\src\user_recipe.jl:158 [inlined]
#
#  [3] apply_recipe(::AbstractDict{Symbol, Any}, ::Any, ::Any, ::Any, ::Any)
#
#    @ RecipesPipeline C:\Users\BHASKAR BARMAN\.julia\packages\RecipesBase\z10lo\src\RecipesBase.jl:300
#
#  [4] _process_userrecipes!(plt::Any, plotattributes::Any, args::Any)
#
#    @ RecipesPipeline C:\Users\BHASKAR BARMAN\.julia\packages\RecipesPipeline\XxUHt\src\user_recipe.jl:38
#
#  [5] recipe_pipeline!(plt::Any, plotattributes::Any, args::Any)
#
#    @ RecipesPipeline C:\Users\BHASKAR BARMAN\.julia\packages\RecipesPipeline\XxUHt\src\RecipesPipeline.jl:72
#
#  [6] _plot!(plt::Plots.Plot, plotattributes::Any, args::Any)
#
#    @ Plots C:\Users\BHASKAR BARMAN\.julia\packages\Plots\bMtsB\src\plot.jl:223
#
#  [7] plot(::Any, ::Vararg{Any}; kw::Base.Pairs{Symbol, V, Tuple{Vararg{Symbol, N}}, NamedTuple{names, T}} where {V, N, names, T<:Tuple{Vararg{Any, N}}})
#
#    @ Plots C:\Users\BHASKAR BARMAN\.julia\packages\Plots\bMtsB\src\plot.jl:102
#
#  [8] top-level scope
#
#    @ c:\Users\BHASKAR BARMAN\OneDrive\4th sem\julia\Intro_to_Julia-main\Notebooks\7 - Plotting.ipynb:2

# %%
using Pkg
Pkg.add("Plots")
using Plots
# Out:
#     Updating registry at `C:\Users\BHASKAR BARMAN\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed x265_jll ───────────────────── v3.5.0+0
#    Installed JpegTurbo_jll ──────────────── v2.1.91+0
#    Installed Opus_jll ───────────────────── v1.3.2+0
#    Installed LERC_jll ───────────────────── v3.0.0+1
#    Installed GR_jll ─────────────────────── v0.71.7+0
#    Installed libfdk_aac_jll ─────────────── v2.0.2+0
#    Installed Libmount_jll ───────────────── v2.35.0+0
#    Installed LoggingExtras ──────────────── v1.0.0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.2+4
#    Installed RelocatableFolders ─────────── v1.0.0
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Formatting ─────────────────── v0.4.2
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.1+1
#    Installed Measures ───────────────────── v0.3.2
#    Installed Contour ────────────────────── v0.6.2
#    Installed Xorg_xcb_util_image_jll ────── v0.4.0+1
#    Installed Xorg_libpthread_stubs_jll ──── v0.1.0+3
#    Installed RecipesPipeline ────────────── v0.6.11
#    Installed PlotUtils ──────────────────── v1.3.4
#    Installed OpenSSL ────────────────────── v1.3.3
#    Installed HTTP ───────────────────────── v1.7.4
#    Installed Cairo_jll ──────────────────── v1.16.1+1
#    Installed Fontconfig_jll ─────────────── v2.13.93+0
#    Installed Xorg_xcb_util_jll ──────────── v0.4.0+1
#    Installed Xorg_libxkbfile_jll ────────── v1.1.0+4
#    Installed Libgpg_error_jll ───────────── v1.42.0+0
#    Installed Xorg_libXinerama_jll ───────── v1.1.4+4
#    Installed Xorg_libXau_jll ────────────── v1.0.9+4
#    Installed IrrationalConstants ────────── v0.2.1
#    Installed Missings ───────────────────── v1.1.0
#    Installed FFMPEG ─────────────────────── v0.4.1
#    Installed Showoff ────────────────────── v1.0.3
#    Installed Qt5Base_jll ────────────────── v5.15.3+2
#    Installed xkbcommon_jll ──────────────── v1.4.1+0
#    Installed Bzip2_jll ──────────────────── v1.0.8+0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.0+1
#    Installed Pipe ───────────────────────── v1.3.0
#    Installed SimpleBufferStream ─────────── v1.1.0
#    Installed HarfBuzz_jll ───────────────── v2.8.1+1
#    Installed LZO_jll ────────────────────── v2.10.1+0
#    Installed SpecialFunctions ───────────── v2.2.0
#    Installed PlotThemes ─────────────────── v3.1.0
#    Installed NaNMath ────────────────────── v1.0.2
#    Installed TranscodingStreams ─────────── v0.9.11
#    Installed fzf_jll ────────────────────── v0.29.0+0
#    Installed GLFW_jll ───────────────────── v3.3.8+0
#    Installed FriBidi_jll ────────────────── v1.0.10+0
#    Installed x264_jll ───────────────────── v2021.5.5+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed FreeType2_jll ──────────────── v2.10.4+0
#    Installed StatsAPI ───────────────────── v1.5.0
#    Installed JLFzf ──────────────────────── v0.1.5
#    Installed DataStructures ─────────────── v0.18.13
#    Installed Colors ─────────────────────── v0.12.10
#    Installed Compat ─────────────────────── v4.6.0
#    Installed CodecZlib ──────────────────── v0.7.1
#    Installed Xorg_libxcb_jll ────────────── v1.13.0+3
#    Installed StatsBase ──────────────────── v0.33.21
#    Installed libpng_jll ─────────────────── v1.6.38+0
#    Installed libaom_jll ─────────────────── v3.4.0+0
#    Installed Scratch ────────────────────── v1.1.1
#    Installed ColorTypes ─────────────────── v0.11.4
#    Installed Xorg_libXext_jll ───────────── v1.3.4+4
#    Installed Zstd_jll ───────────────────── v1.5.4+0
#    Installed Expat_jll ──────────────────── v2.4.8+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Libtiff_jll ────────────────── v4.4.0+0
#    Installed Plots ──────────────────────── v1.38.6
#    Installed Libffi_jll ─────────────────── v3.2.2+1
#    Installed Xorg_libXrender_jll ────────── v0.9.10+4
#    Installed OrderedCollections ─────────── v1.4.1
#    Installed ColorVectorSpace ───────────── v0.9.10
#    Installed GR ─────────────────────────── v0.71.7
#    Installed Ogg_jll ────────────────────── v1.3.5+1
#    Installed ChainRulesCore ─────────────── v1.15.7
#    Installed Xorg_libXi_jll ─────────────── v1.7.10+4
#    Installed XSLT_jll ───────────────────── v1.1.34+0
#    Installed Reexport ───────────────────── v1.2.2
#    Installed LogExpFunctions ────────────── v0.3.23
#    Installed OpenSpecFun_jll ────────────── v0.5.5+0
#    Installed MacroTools ─────────────────── v0.5.10
#    Installed Xorg_libXcursor_jll ────────── v1.2.0+4
#    Installed InverseFunctions ───────────── v0.1.8
#    Installed Libuuid_jll ────────────────── v2.36.0+0
#    Installed Wayland_protocols_jll ──────── v1.25.0+0
#    Installed libass_jll ─────────────────── v0.15.1+0
#    Installed Graphite2_jll ──────────────── v1.3.14+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.9+1
#    Installed DocStringExtensions ────────── v0.9.3
#    Installed Pixman_jll ─────────────────── v0.40.1+0
#    Installed XML2_jll ───────────────────── v2.10.3+0
#    Installed Wayland_jll ────────────────── v1.21.0+0
#    Installed BitFlags ───────────────────── v0.1.7
#    Installed Gettext_jll ────────────────── v0.21.0+0
#    Installed OpenSSL_jll ────────────────── v1.1.20+0
#    Installed Xorg_xtrans_jll ────────────── v1.4.0+3
#    Installed Latexify ───────────────────── v0.15.18
#    Installed FFMPEG_jll ─────────────────── v4.4.2+2
#    Installed Libgcrypt_jll ──────────────── v1.8.7+0
#    Installed Xorg_xkeyboard_config_jll ──── v2.27.0+4
#    Installed Xorg_libXrandr_jll ─────────── v1.5.2+4
#    Installed RecipesBase ────────────────── v1.3.3
#    Installed DataAPI ────────────────────── v1.14.0
#    Installed FixedPointNumbers ──────────── v0.8.4
#    Installed Xorg_libXfixes_jll ─────────── v5.0.3+4
#    Installed LAME_jll ───────────────────── v3.100.1+0
#    Installed Libiconv_jll ───────────────── v1.16.1+2
#    Installed Glib_jll ───────────────────── v2.74.0+2
#    Installed IniFile ────────────────────── v0.5.1
#    Installed LaTeXStrings ───────────────── v1.3.0
#    Installed ColorSchemes ───────────────── v3.20.0
#    Installed URIs ───────────────────────── v1.4.2
#    Installed libvorbis_jll ──────────────── v1.3.7+1
#    Installed Libglvnd_jll ───────────────── v1.6.0+0
#    Installed Requires ───────────────────── v1.3.0
#    Installed Xorg_libX11_jll ────────────── v1.6.9+4
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.3+4
#    Installed SortingAlgorithms ──────────── v1.1.0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed ChangesOfVariables ─────────── v0.1.6
#     Updating `C:\Users\BHASKAR BARMAN\.julia\environments\v1.8\Project.toml`
#   [91a5bcdd] + Plots v1.38.6
#     Updating `C:\Users\BHASKAR BARMAN\.julia\environments\v1.8\Manifest.toml`
#   [d1d4a3ce] + BitFlags v0.1.7
#   [d360d2e6] + ChainRulesCore v1.15.7
#   [9e997f8a] + ChangesOfVariables v0.1.6
#   [944b1d66] + CodecZlib v0.7.1
#   [35d6a980] + ColorSchemes v3.20.0
#   [3da002f7] + ColorTypes v0.11.4
#   [c3611d14] + ColorVectorSpace v0.9.10
#   [5ae59095] + Colors v0.12.10
#   [34da2185] + Compat v4.6.0
#   [d38c429a] + Contour v0.6.2
#   [9a962f9c] + DataAPI v1.14.0
#   [864edb3b] + DataStructures v0.18.13
#   [ffbed154] + DocStringExtensions v0.9.3
#   [c87230d0] + FFMPEG v0.4.1
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [59287772] + Formatting v0.4.2
#   [28b8d3ca] + GR v0.71.7
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.7.4
#   [83e8ac13] + IniFile v0.5.1
#   [3587e190] + InverseFunctions v0.1.8
#   [92d709cd] + IrrationalConstants v0.2.1
#   [1019f520] + JLFzf v0.1.5
#   [b964fa9f] + LaTeXStrings v1.3.0
#   [23fbe1c1] + Latexify v0.15.18
#   [2ab3a3ac] + LogExpFunctions v0.3.23
#   [e6f89c97] + LoggingExtras v1.0.0
#   [1914dd2f] + MacroTools v0.5.10
#   [442fdcdd] + Measures v0.3.2
#   [e1d29d7a] + Missings v1.1.0
#   [77ba4419] + NaNMath v1.0.2
#   [4d8831e6] + OpenSSL v1.3.3
#   [bac558e1] + OrderedCollections v1.4.1
#   [b98c9c47] + Pipe v1.3.0
#   [ccf2f8ad] + PlotThemes v3.1.0
#   [995b91a9] + PlotUtils v1.3.4
#   [91a5bcdd] + Plots v1.38.6
#   [3cdcf5f2] + RecipesBase v1.3.3
#   [01d81517] + RecipesPipeline v0.6.11
#   [189a3867] + Reexport v1.2.2
#   [05181044] + RelocatableFolders v1.0.0
#   [ae029012] + Requires v1.3.0
#   [6c6a2e73] + Scratch v1.1.1
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.1.0
#   [a2af1166] + SortingAlgorithms v1.1.0
#   [276daf66] + SpecialFunctions v2.2.0
#   [82ae8749] + StatsAPI v1.5.0
#   [2913bbd2] + StatsBase v0.33.21
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.9.11
#   [5c2747f8] + URIs v1.4.2
#   [1cfade01] + UnicodeFun v0.4.1
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.8+0
#   [83423d85] + Cairo_jll v1.16.1+1
#   [2e619515] + Expat_jll v2.4.8+0
#   [b22a6f82] + FFMPEG_jll v4.4.2+2
#   [a3f928ae] + Fontconfig_jll v2.13.93+0
#   [d7e528f0] + FreeType2_jll v2.10.4+0
#   [559328eb] + FriBidi_jll v1.0.10+0
#   [0656b61e] + GLFW_jll v3.3.8+0
#   [d2c73de3] + GR_jll v0.71.7+0
#   [78b55507] + Gettext_jll v0.21.0+0
#   [7746bdde] + Glib_jll v2.74.0+2
#   [3b182d85] + Graphite2_jll v1.3.14+0
#   [2e76f6c2] + HarfBuzz_jll v2.8.1+1
#   [aacddb02] + JpegTurbo_jll v2.1.91+0
#   [c1c5ebd0] + LAME_jll v3.100.1+0
#   [88015f11] + LERC_jll v3.0.0+1
#   [dd4b983a] + LZO_jll v2.10.1+0
# ⌅ [e9f186c6] + Libffi_jll v3.2.2+1
#   [d4300ac3] + Libgcrypt_jll v1.8.7+0
#   [7e76a0d4] + Libglvnd_jll v1.6.0+0
#   [7add5ba3] + Libgpg_error_jll v1.42.0+0
#   [94ce4f54] + Libiconv_jll v1.16.1+2
#   [4b2f31a3] + Libmount_jll v2.35.0+0
#   [89763e89] + Libtiff_jll v4.4.0+0
#   [38a345b3] + Libuuid_jll v2.36.0+0
#   [e7412a2a] + Ogg_jll v1.3.5+1
#   [458c3c95] + OpenSSL_jll v1.1.20+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [91d4177d] + Opus_jll v1.3.2+0
#   [30392449] + Pixman_jll v0.40.1+0
#   [ea2cea3b] + Qt5Base_jll v5.15.3+2
#   [a2964d1f] + Wayland_jll v1.21.0+0
#   [2381bf8a] + Wayland_protocols_jll v1.25.0+0
#   [02c8fc9c] + XML2_jll v2.10.3+0
#   [aed1982a] + XSLT_jll v1.1.34+0
#   [4f6342f7] + Xorg_libX11_jll v1.6.9+4
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.9+4
#   [935fb764] + Xorg_libXcursor_jll v1.2.0+4
#   [a3789734] + Xorg_libXdmcp_jll v1.1.3+4
#   [1082639a] + Xorg_libXext_jll v1.3.4+4
#   [d091e8ba] + Xorg_libXfixes_jll v5.0.3+4
#   [a51aa0fd] + Xorg_libXi_jll v1.7.10+4
#   [d1454406] + Xorg_libXinerama_jll v1.1.4+4
#   [ec84b674] + Xorg_libXrandr_jll v1.5.2+4
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.10+4
#   [14d82f49] + Xorg_libpthread_stubs_jll v0.1.0+3
#   [c7cfdc94] + Xorg_libxcb_jll v1.13.0+3
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.0+4
#   [12413925] + Xorg_xcb_util_image_jll v0.4.0+1
#   [2def613f] + Xorg_xcb_util_jll v0.4.0+1
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.0+1
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.9+1
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.1+1
#   [35661453] + Xorg_xkbcomp_jll v1.4.2+4
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.27.0+4
#   [c5fb5394] + Xorg_xtrans_jll v1.4.0+3
#   [3161d3a3] + Zstd_jll v1.5.4+0
# ⌅ [214eeab7] + fzf_jll v0.29.0+0
#   [a4ae2306] + libaom_jll v3.4.0+0
#   [0ac62f75] + libass_jll v0.15.1+0
#   [f638f0a6] + libfdk_aac_jll v2.0.2+0
#   [b53b4c65] + libpng_jll v1.6.38+0
#   [f27f6e37] + libvorbis_jll v1.3.7+1
#   [1270edf5] + x264_jll v2021.5.5+0
#   [dfaa095f] + x265_jll v3.5.0+0
#   [d8fb68d0] + xkbcommon_jll v1.4.1+0
#   [8bb1440f] + DelimitedFiles
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [e66e0078] + CompilerSupportLibraries_jll v1.0.1+0
#   [4536629a] + OpenBLAS_jll v0.3.20+0
#   [05823500] + OpenLibm_jll v0.8.1+0
#   [efcefdf7] + PCRE2_jll v10.40.0+0
#   [8e850b90] + libblastrampoline_jll v5.1.1+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ StatsAPI
#   ✓ TensorCore
#   ✓ Contour
#   ✓ Pipe
#   ✓ OpenLibm_jll
#   ✓ Measures
#   ✓ LaTeXStrings
#   ✓ CompilerSupportLibraries_jll
#   ✓ InverseFunctions
#   ✓ Grisu
#   ✓ FixedPointNumbers
#   ✓ Compat
#   ✓ OrderedCollections
#   ✓ Reexport
#   ✓ Unzip
#   ✓ Requires
#   ✓ DocStringExtensions
#   ✓ MacroTools
#   ✓ IniFile
#   ✓ SimpleBufferStream
#   ✓ URIs
#   ✓ IrrationalConstants
#   ✓ Formatting
#   ✓ PCRE2_jll
#   ✓ DataAPI
#   ✓ BitFlags
#   ✓ Scratch
#   ✓ UnicodeFun
#   ✓ LoggingExtras
#   ✓ TranscodingStreams
#   ✓ OpenSSL_jll
#   ✓ Graphite2_jll
#   ✓ Libmount_jll
#   ✓ Bzip2_jll
#   ✓ RecipesBase
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ libfdk_aac_jll
#   ✓ Pixman_jll
#   ✓ LAME_jll
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ JpegTurbo_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ Ogg_jll
#   ✓ x265_jll
#   ✓ x264_jll
#   ✓ libaom_jll
#   ✓ Zstd_jll
#   ✓ Expat_jll
#   ✓ LZO_jll
#   ✓ Xorg_xtrans_jll
#   ✓ Opus_jll
#   ✓ Libiconv_jll
#   ✓ Libffi_jll
#   ✓ Libgpg_error_jll
#   ✓ Wayland_protocols_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ NaNMath
#   ✓ Libuuid_jll
#   ✓ FriBidi_jll
#   ✓ OpenBLAS_jll
#   ✓ Showoff
#   ✓ OpenSpecFun_jll
#   ✓ Missings
#   ✓ ChainRulesCore
#   ✓ RelocatableFolders
#   ✓ CodecZlib
#   ✓ DataStructures
#   ✓ ColorTypes
#   ✓ Latexify
#   ✓ FreeType2_jll
#   ✓ OpenSSL
#   ✓ JLFzf
#   ✓ libblastrampoline_jll
#   ✓ libvorbis_jll
#   ✓ Libtiff_jll
#   ✓ XML2_jll
#   ✓ SortingAlgorithms
#   ✓ Libgcrypt_jll
#   ✓ ChangesOfVariables
#   ✓ Fontconfig_jll
#   ✓ Wayland_jll
#   ✓ Gettext_jll
#   ✓ XSLT_jll
#   ✓ Glib_jll
#   ✓ Xorg_libxcb_jll
#   ✓ LogExpFunctions
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_jll
#   ✓ HTTP
#   ✓ Colors
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ StatsBase
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ Xorg_libXcursor_jll
#   ✓ Cairo_jll
#   ✓ Xorg_libXi_jll
#   ✓ SpecialFunctions
#   ✓ Xorg_xkbcomp_jll
#   ✓ HarfBuzz_jll
#   ✓ GLFW_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ libass_jll
#   ✓ xkbcommon_jll
#   ✓ FFMPEG_jll
#   ✓ Qt5Base_jll
#   ✓ ColorVectorSpace
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ GR
#   ✓ ColorSchemes
#   ✓ PlotUtils
#   ✓ RecipesPipeline
#   ✓ PlotThemes
#   ✓ Plots
#   125 dependencies successfully precompiled in 428 seconds. 17 already precompiled.

# %% [markdown]
# One of the advantages to `Plots.jl` is that it allows you to seamlessly change backends. In this notebook, we'll try out the `gr()` and `plotlyjs()` backends.<br>
#
# In the name of scientific inquiry, let's use this notebook to examine the relationship between the global temperature and the number of pirates between roughly 1860 and 2000.

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17];

# %% [markdown]
# Plots supports multiple backends — that is, libraries that actually do the drawing — all with the same API. To start out, let's try the GR backend.  You choose it with a call to `gr()`:

# %%
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# and now we can use commands like `plot` and `scatter` to generate plots.

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points")

# %% [markdown]
# The `!` at the end of the `scatter!` function name makes `scatter!` a mutating function, indicating that the scattered points will be added onto the pre-existing plot.
#
# In contrast, see what happens when you replace `scatter!` in the above with the non-mutating function `scatter`.
#
# Next, let's update this plot with the `xlabel!`, `ylabel!`, and `title!` commands to add more information to our plot.

# %%
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")

# %% [markdown]
# This still doesn't look quite right. The number of pirates has decreased since 1860, so reading the plot from left to right is like looking backwards in time rather than forwards. Let's flip the x axis to better see how pirate populations have caused global temperatures to change over time!

# %%
xflip!()

# %% [markdown]
# And there we have it!
#
# Note: We've had some confusion about this exercise. :) This is a joke about how people often conflate correlation and causation.
#
# **Without changing syntax, we can create this plot with the UnicodePlots backend**

# %%
using Pkg

# %%
Pkg.add("UnicodePlots")
unicodeplots()
# Out:
#     Updating registry at `C:\Users\BHASKAR BARMAN\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed StaticArraysCore ─ v1.4.0
#    Installed StaticArrays ───── v1.5.16
#    Installed MarchingCubes ──── v0.1.6
#    Installed Crayons ────────── v4.1.1
#    Installed UnicodePlots ───── v3.4.0
#     Updating `C:\Users\BHASKAR BARMAN\.julia\environments\v1.8\Project.toml`
#   [b8865327] + UnicodePlots v3.4.0
#     Updating `C:\Users\BHASKAR BARMAN\.julia\environments\v1.8\Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [299715c1] + MarchingCubes v0.1.6
#   [90137ffa] + StaticArrays v1.5.16
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [b8865327] + UnicodePlots v3.4.0
# Precompiling project...
#   ✓ StaticArraysCore
#   ✓ Crayons
#   ✓ StaticArrays
#   ✓ MarchingCubes
#   ✓ UnicodePlots
#   5 dependencies successfully precompiled in 54 seconds. 142 already precompiled.
# Plots.UnicodePlotsBackend()

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points") 
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")
# Out:
# UndefVarError: numpirates not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ c:\Users\BHASKAR BARMAN\OneDrive\4th sem\julia\Intro_to_Julia-main\Notebooks\7 - Plotting.ipynb:1

# %% [markdown]
# And notice how this second plot differs from the first!  Using text like this is a little silly in a Jupyter notebook where we have fancy drawing capabilities, but it can be very useful for quick and dirty visualization in a terminal.

# %% [markdown]
# https://github.com/JuliaPlots/UnicodePlots.jl <br/>
#
# For more examples and documentation visit UnicodePlot github repo!

# %% [markdown]
# ### Exercises
#
# #### 8.1
# Given
# ```julia
# x = -10:10
# ```
# plot y vs. x for $y = x^2$.  You may want to change backends back again.

# %%
x=-10:10
# Out:
# -10:10

# %%
using Plots

# %% [markdown]
# #### 8.2
# Execute the following code

# %%
Plots.theme(:dark)

# %%
p1 = plot(x, x,title="1",color="red")
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout = (2,2))

# %%
savefig("test.plot.svg")
# Out:
# "c:\\Users\\BHASKAR BARMAN\\OneDrive\\4th sem\\julia\\Intro_to_Julia-main\\Notebooks\\test.plot.svg"

# %% [markdown]
# and then create a $4x1$ plot that uses `p1`, `p2`, `p3`, and `p4` as subplots.
